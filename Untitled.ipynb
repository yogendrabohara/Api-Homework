# %%
# !pip install openweathermapy
# Out:
# Requirement already satisfied: openweathermapy in c:\users\yogi\anaconda\lib\site-packages (0.6.6)
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 19.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import openweathermapy.core as owm
# Import API key
#import api_keys

api_key="df04bb1077dea60a218c4a0244319eab"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
#print(cities)
len(cities)
# Out:
# 618

# %%
# import API Key from config file
api_key="df04bb1077dea60a218c4a0244319eab"
# Create settings dictionary with information we're interested in
settings = {"units": "imperial", "appid": api_key}
print(settings)
# Initialize data frame to store data from API calls
WeatherPy_df =pd.DataFrame(columns = ["City","Cloudiness", "Country",
                                    "Date", "Max Temp", "Wind Speed", 
                                    "Lat","Lng", "Humidity"])
print(WeatherPy_df)
#Perform API calls and send retrieved data to the WeatherPy data frame
# counter to count the number of calls to API
count = 1
# error count to record how many cities the API responds back with no data.
err = 0
# counter to count the number of call sets
sets = 1
# index for the data frame WeatherPy data frame
index = 0
print(f'Beginning Data Retrieval \n ........................')
for city in cities:
    try:
        city1=city.replace("","%20")
        print(f'Processing Record {count} of Set {sets} | {city}' )
        print(f'{owm.BASE_URL}weather?q={city1}&units=imperial&APPID={api_key}')
        city_stats = owm.get_current(city, **settings)
        WeatherPy_df.set_value(index, "City", city_stats["name"])
        WeatherPy_df.set_value(index, "Cloudiness", city_stats("clouds.all"))
        WeatherPy_df.set_value(index, "Country", city_stats("sys.country"))
        WeatherPy_df.set_value(index, "Date", city_stats("dt"))
        WeatherPy_df.set_value(index, "Max Temp", city_stats("main.temp_max"))
        WeatherPy_df.set_value(index, "Wind Speed", city_stats("wind.speed"))
        WeatherPy_df.set_value(index, "Lat", city_stats("coord.lat"))
        WeatherPy_df.set_value(index, "Lng", city_stats("coord.lon"))
        WeatherPy_df.set_value(index, "Humidity", city_stats("main.humidity"))
        index = index +1 
    except Exception as e:
        print(e)
        err= err+1
    count = count+1
    if count == 1: 
        
        count = 1 
        sets = sets+1
        

print("end of stats loop")
print(f'Could not get data for {err} cities')
# Out:
# {'units': 'imperial', 'appid': 'df04bb1077dea60a218c4a0244319eab'}
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Max Temp, Wind Speed, Lat, Lng, Humidity]
# Index: []
# Beginning Data Retrieval
#  ........................
# Processing Record 1 of Set 1 | magadan
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20a%20g%20a%20d%20a%20n%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# C:\Users\yogi\ANACONDA\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yogi\ANACONDA\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yogi\ANACONDA\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yogi\ANACONDA\lib\site-packages\ipykernel_launcher.py:30: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yogi\ANACONDA\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yogi\ANACONDA\lib\site-packages\ipykernel_launcher.py:32: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yogi\ANACONDA\lib\site-packages\ipykernel_launcher.py:33: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yogi\ANACONDA\lib\site-packages\ipykernel_launcher.py:34: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\yogi\ANACONDA\lib\site-packages\ipykernel_launcher.py:35: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing Record 2 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20a%20t%20a%20u%20r%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 3 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=%20r%20i%20k%20i%20t%20e%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 4 of Set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20a%20m%20b%20o%20u%20s%20 %20v%20i%20r%20i%20e%20u%20x%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 5 of Set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=%20t%20a%20o%20l%20a%20n%20a%20r%20o%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 6 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=%20p%20u%20n%20t%20a%20 %20a%20r%20e%20n%20a%20s%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 7 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?q=%20h%20e%20r%20m%20a%20n%20u%20s%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 8 of Set 1 | clonakilty
# http://api.openweathermap.org/data/2.5/weather?q=%20c%20l%20o%20n%20a%20k%20i%20l%20t%20y%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 9 of Set 1 | yithion
# http://api.openweathermap.org/data/2.5/weather?q=%20y%
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20u%20n%20g%20a%20i%20p%20e%20n%20u%20h%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 95 of Set 1 | zhicheng
# http://api.openweathermap.org/data/2.5/weather?q=%20z%20h%20i%20c%20h%20e%20n%20g%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 96 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=%20t%20a%20s%20i%20i%20l%20a%20q%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 97 of Set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?q=%20c%20i%20d%20r%20e%20i%20r%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 98 of Set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?q=%20l%20e%20b%20u%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 99 of Set 1 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20o%20l%20u%20n%20g%20a%20r%20v%20i%20k%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 100 of Set 1 | banjar
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20a%20n%20j%20a%20r%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 101 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20e%20t%20h%20e%20l%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 102 of Set 1 | high prairie
# http://api.openweathermap.org/data/2.5/weather?q=%20h%20i%20g%20h%20 %20p%20r%20a%20i%20r%20i%20e%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 103 of Set 1 | grand centre
# http://api.openweathermap.org/data/2.5/weather?q=%20g%20r%20a%20n%20d%20 %20c%20e%20n%20t%20r%20e%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 104 of Set 1 | rolim de moura
# http://api.openweathermap.org/data/2.5/weather?q=%20r%20o%20l%20i%20m%20 %20d%20e%20 %20m%20o%20u%20r%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 105 of Set 1 | mbandaka
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20b%20a%20n%20d%20a%20k%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 106 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?q=%20a%20l%20b%20a%20n%20y%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 107 of Set 1 | berlevag
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20e%20r%20l%20e%20v%20a%20g%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 108 of Set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?q=%20l%20o%20n%20g%20y%20e%20a%20r%20b%20y%20e%20n%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 109 of Set 1 | karamea
# http://api.openweathermap.org/data/2.5/weather?q=%20k%20a%20r%20a%20m%20e%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 110 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?q=%20v%20a%20i%20n%20i%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 111 of Set 1 | lampazos de naranjo
# http://api.openweathermap.org/data/2.5/weather?q=%20l%20a%20m%20p%20a%20z%20o%20s%20 %20d%20e%20 %20n%20a%20r%20a%20n%20j%20o%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 112 of Set 1 | kabompo
# http://api.openweathermap.org/data/2.5/weather?q=%20k%20a%20b%20o%20m%20p%20o%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 113 of Set 1 | hirara
# http://api.openweathermap.org/data/2.5/weather?q=%20h%20i%20r%20a%20r%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 114 of Set 1 | dinsor
# http://api.openweathermap.org/data/2.5/weather?q=%20d%20i%20n%20s%20o%20r%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 115 of Set 1 | seidu
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20e%20i%20d%20u%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 116 of Set 1 | burnie
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20u%20r%20n%20i%20e%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 117 of Set 1 | kenai
# http://api.openweathermap.org/data/2.5/weather?q=%20k%20e%20n%20a%20i%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 118 of Set 1 | zhanaozen
# http://api.openweathermap.org/data/2.5/weather?q=%20z%20h%20a%20n%20a%20o%20z%20e%20n%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 119 of Set 1 | ancud
# http://api.openweathermap.org/data/2.5/weather?q=%20a%20n%20c%20u%20d%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 120 of Set 1 | burla
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20u%20r%20l%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 121 of Set 1 | itarema
# http://api.openweathermap.org/data/2.5/weather?q=%20i%20t%20a%20r%20e%20m%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 122 of Set 1 | norman wells
# http://api.openweathermap.org/data/2.5/weather?q=%20n%20o%20r%20m%20a%20n%20 %20w%20e%20l%20l%20s%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 123 of Set 1 | alofi
# http://api.openweathermap.org/data/2.5/weather?q=%20a%20l%20o%20f%20i%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 124 of Set 1 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?q=%20g%20r%20a%20n%20d%20 %20g%20a%20u%20b%20e%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 125 of Set 1 | nikel
# http://api.openweathermap.org/data/2.5/weather?q=%20n%20i%20k%20e%20l%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 126 of Set 1 | catanzaro
# http://api.openweathermap.org/data/2.5/weather?q=%20c%20a%20t%20a%20n%20z%20a%20r%20o%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 127 of Set 1 | xiamen
# http://api.openweathermap.org/data/2.5/weather?q=%20x%20i%20a%20m%20e%20n%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 128 of Set 1 | buariki
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20u%20a%20r%20i%20k%20i%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 129 of Set 1 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?q=%20k%20a%20v%20a%20r%20a%20t%20t%20i%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 130 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?q=%20e%20a%20s%20t%20 %20l%20o%20n%20d%20o%20n%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 131 of Set 1 | narsaq
# http://api.openweathermap.org/data/2.5/weather?q=%20n%20a%20r%20s%20a%20q%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 132 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?q=%20t%20h%20o%20m%20p%20s%20o%20n%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 133 of Set 1 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?q=%20y%20e%20n%20a%20g%20o%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 134 of Set 1 | yatou
# http://api.openweathermap.org/data/2.5/weather?q=%20y%20a%20t%20o%20u%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 135 of Set 1 | nuevo progreso
# http://api.openweathermap.org/data/2.5/weather?q=%20n%20u%20e%20v%20o%20 %20p%20r%20o%20g%20r%20e%20s%20o%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 136 of Set 1 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?q=%20y%20e%20r%20b%20o%20g%20a%20c%20h%20e%20n%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 137 of Set 1 | airai
# http://api.openweathermap.org/data/2.5/weather?q=%20a%20i%20r%20a%20i%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 138 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20a%20r%20r%20o%20w%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 139 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather
20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 225 of Set 1 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?q=%20v%20a%20i%20t%20u%20p%20u%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 226 of Set 1 | aktanysh
# http://api.openweathermap.org/data/2.5/weather?q=%20a%20k%20t%20a%20n%20y%20s%20h%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 227 of Set 1 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20e%20u%20l%20a%20b%20o%20h%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 228 of Set 1 | furano
# http://api.openweathermap.org/data/2.5/weather?q=%20f%20u%20r%20a%20n%20o%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 229 of Set 1 | wajid
# http://api.openweathermap.org/data/2.5/weather?q=%20w%20a%20j%20i%20d%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 230 of Set 1 | camana
# http://api.openweathermap.org/data/2.5/weather?q=%20c%20a%20m%20a%20n%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 231 of Set 1 | athens
# http://api.openweathermap.org/data/2.5/weather?q=%20a%20t%20h%20e%20n%20s%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 232 of Set 1 | baykit
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20a%20y%20k%20i%20t%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 233 of Set 1 | huanren
# http://api.openweathermap.org/data/2.5/weather?q=%20h%20u%20a%20n%20r%20e%20n%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 234 of Set 1 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?q=%20f%20o%20r%20t%20 %20n%20e%20l%20s%20o%20n%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 235 of Set 1 | maceio
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20a%20c%20e%20i%20o%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 236 of Set 1 | naze
# http://api.openweathermap.org/data/2.5/weather?q=%20n%20a%20z%20e%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 237 of Set 1 | monte azul
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20o%20n%20t%20e%20 %20a%20z%20u%20l%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 238 of Set 1 | iberia
# http://api.openweathermap.org/data/2.5/weather?q=%20i%20b%20e%20r%20i%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 239 of Set 1 | sabya
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20a%20b%20y%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 240 of Set 1 | broken hill
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20r%20o%20k%20e%20n%20 %20h%20i%20l%20l%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 241 of Set 1 | amderma
# http://api.openweathermap.org/data/2.5/weather?q=%20a%20m%20d%20e%20r%20m%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 242 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=%20y%20e%20l%20l%20o%20w%20k%20n%20i%20f%20e%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 243 of Set 1 | bargal
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20a%20r%20g%20a%20l%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 244 of Set 1 | oneonta
# http://api.openweathermap.org/data/2.5/weather?q=%20o%20n%20e%20o%20n%20t%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 245 of Set 1 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?q=%20z%20h%20i%20g%20a%20n%20s%20k%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 246 of Set 1 | namibe
# http://api.openweathermap.org/data/2.5/weather?q=%20n%20a%20m%20i%20b%20e%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 247 of Set 1 | matara
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20a%20t%20a%20r%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 248 of Set 1 | punta de bombon
# ...
# Processing Record 533 of Set 1 | xingyi
# http://api.openweathermap.org/data/2.5/weather?q=%20x%20i%20n%20g%20y%20i%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 534 of Set 1 | sabang
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20a%20b%20a%20n%20g%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 535 of Set 1 | miandoab
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20i%20a%20n%20d%20o%20a%20b%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 536 of Set 1 | kaoma
# http://api.openweathermap.org/data/2.5/weather?q=%20k%20a%20o%20m%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 537 of Set 1 | atyrau
# http://api.openweathermap.org/data/2.5/weather?q=%20a%20t%20y%20r%20a%20u%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 538 of Set 1 | kasongo-lunda
# http://api.openweathermap.org/data/2.5/weather?q=%20k%20a%20s%20o%20n%20g%20o%20-%20l%20u%20n%20d%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 539 of Set 1 | valley station
# http://api.openweathermap.org/data/2.5/weather?q=%20v%20a%20l%20l%20e%20y%20 %20s%20t%20a%20t%20i%20o%20n%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 540 of Set 1 | pizarro
# http://api.openweathermap.org/data/2.5/weather?q=%20p%20i%20z%20a%20r%20r%20o%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 541 of Set 1 | zyryanskoye
# http://api.openweathermap.org/data/2.5/weather?q=%20z%20y%20r%20y%20a%20n%20s%20k%20o%20y%20e%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 542 of Set 1 | turbana
# http://api.openweathermap.org/data/2.5/weather?q=%20t%20u%20r%20b%20a%20n%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 543 of Set 1 | takoradi
# http://api.openweathermap.org/data/2.5/weather?q=%20t%20a%20k%20o%20r%20a%20d%20i%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 544 of Set 1 | aitape
# http://api.openweathermap.org/data/2.5/weather?q=%20a%20i%20t%20a%20p%20e%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 545 of Set 1 | bestobe
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20e%20s%20t%20o%20b%20e%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 546 of Set 1 | sitka
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20i%20t%20k%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 547 of Set 1 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?q=%20q%20u%20a%20t%20r%20e%20 %20c%20o%20c%20o%20s%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 548 of Set 1 | kimbe
# http://api.openweathermap.org/data/2.5/weather?q=%20k%20i%20m%20b%20e%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 549 of Set 1 | ramhormoz
# http://api.openweathermap.org/data/2.5/weather?q=%20r%20a%20m%20h%20o%20r%20m%20o%20z%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 550 of Set 1 | nalut
# http://api.openweathermap.org/data/2.5/weather?q=%20n%20a%20l%20u%20t%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 551 of Set 1 | juneau
# http://api.openweathermap.org/data/2.5/weather?q=%20j%20u%20n%20e%20a%20u%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 552 of Set 1 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?q=%20c%20o%20q%20u%20i%20m%20b%20o%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 553 of Set 1 | nhamunda
# http://api.openweathermap.org/data/2.5/weather?q=%20n%20h%20a%20m%20u%20n%20d%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 554 of Set 1 | verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?q=%20v%20e%20r%20k%20h%20n%20e%20v%20i%20l%20y%20u%20y%20s%20k%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 555 of Set 1 | qunduz
# http://api.openweathermap.org/data/2.5/weather?q=%20q%20u%20n%20d%20u%20z%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 556 of Set 1 | bataraza
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20a%20t%20a%20r%20a%20z%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 557 of Set 1 | chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?q=%20c%20h%20e%20r%20n%20y%20s%20h%20e%20v%20s%20k%20i%20y%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 558 of Set 1 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?q=%20t%20a%20z%20o%20v%20s%20k%20i%20y%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 559 of Set 1 | wabana
# http://api.openweathermap.org/data/2.5/weather?q=%20w%20a%20b%20a%20n%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 560 of Set 1 | balkanabat
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20a%20l%20k%20a%20n%20a%20b%20a%20t%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 561 of Set 1 | royan
# http://api.openweathermap.org/data/2.5/weather?q=%20r%20o%20y%20a%20n%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 562 of Set 1 | senai
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20e%20n%20a%20i%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 563 of Set 1 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20i%20t%20s%20a%20m%20i%20o%20u%20l%20i%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 564 of Set 1 | bhag
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20h%20a%20g%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 565 of Set 1 | taltal
# http://api.openweathermap.org/data/2.5/weather?q=%20t%20a%20l%20t%20a%20l%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 566 of Set 1 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?q=%20p%20e%20t%20r%20o%20p%20a%20v%20l%20o%20v%20s%20k%20-%20k%20a%20m%20c%20h%20a%20t%20s%20k%20i%20y%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 567 of Set 1 | turbiv
# http://api.openweathermap.org/data/2.5/weather?q=%20t%20u%20r%20b%20i%20v%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 568 of Set 1 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?q=%20a%20n%20t%20o%20f%20a%20g%20a%20s%20t%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 569 of Set 1 | hovd
# http://api.openweathermap.org/data/2.5/weather?q=%20h%20o%20v%20d%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 570 of Set 1 | madimba
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20a%20d%20i%20m%20b%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 571 of Set 1 | madang
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20a%20d%20a%20n%20g%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 572 of Set 1 | conakry
# http://api.openweathermap.org/data/2.5/weather?q=%20c%20o%20n%20a%20k%20r%20y%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 573 of Set 1 | praya
# http://api.openweathermap.org/data/2.5/weather?q=%20p%20r%20a%20y%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 574 of Set 1 | saravan
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20a%20r%20a%20v%20a%20n%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 575 of Set 1 | zeya
# http://api.openweathermap.org/data/2.5/weather?q=%20z%20e%20y%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 576 of Set 1 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20a%20n%20i%20i%20t%20s%20o%20q%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 577 of Set 1 | lolua
# http://api.openweathermap.org/data/2.5/weather?q=%20l%20o%20l%20u%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 578 of Set 1 | maryborough
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20a%20r%20y%20b%20o%20r%20o%20u%20g%20h%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 579 of Set 1 | mamallapuram
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20a%20m%20a%20l%20l%20a%20p%20u%20r%20a%20m%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 580 of Set 1 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?q=%20l%20e%20n%20i%20n%20g%20r%20a%20d%20s%20k%20i%20y%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 581 of Set 1 | morehead
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20o%20r%20e%20h%20e%20a%20d%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 582 of Set 1 | porto novo
# http://api.openweathermap.org/data/2.5/weather?q=%20p%20o%20r%20t%20o%20 %20n%20o%20v%20o%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 583 of Set 1 | ust-omchug
# http://api.openweathermap.org/data/2.5/weather?q=%20u%20s%20t%20-%20o%20m%20c%20h%20u%20g%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 584 of Set 1 | salisbury
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20a%20l%20i%20s%20b%20u%20r%20y%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 585 of Set 1 | beaverlodge
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20e%20a%20v%20e%20r%20l%20o%20d%20g%20e%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 586 of Set 1 | robertson
# http://api.openweathermap.org/data/2.5/weather?q=%20r%20o%20b%20e%20r%20t%20s%20o%20n%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 587 of Set 1 | kysyl-syr
# http://api.openweathermap.org/data/2.5/weather?q=%20k%20y%20s%20y%20l%20-%20s%20y%20r%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 588 of Set 1 | yambio
# http://api.openweathermap.org/data/2.5/weather?q=%20y%20a%20m%20b%20i%20o%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 589 of Set 1 | pasco
# http://api.openweathermap.org/data/2.5/weather?q=%20p%20a%20s%20c%20o%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 590 of Set 1 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20a%20i%20n%20t%20-%20f%20r%20a%20n%20c%20o%20i%20s%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 591 of Set 1 | gasa
# http://api.openweathermap.org/data/2.5/weather?q=%20g%20a%20s%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 592 of Set 1 | bubaque
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20u%20b%20a%20q%20u%20e%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 593 of Set 1 | cataguases
# http://api.openweathermap.org/data/2.5/weather?q=%20c%20a%20t%20a%20g%20u%20a%20s%20e%20s%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 594 of Set 1 | phan thiet
# http://api.openweathermap.org/data/2.5/weather?q=%20p%20h%20a%20n%20 %20t%20h%20i%20e%20t%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 595 of Set 1 | ust-ordynskiy
# http://api.openweathermap.org/data/2.5/weather?q=%20u%20s%20t%20-%20o%20r%20d%20y%20n%20s%20k%20i%20y%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 596 of Set 1 | traralgon
# http://api.openweathermap.org/data/2.5/weather?q=%20t%20r%20a%20r%20a%20l%20g%20o%20n%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 597 of Set 1 | laguna
# http://api.openweathermap.org/data/2.5/weather?q=%20l%20a%20g%20u%20n%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 598 of Set 1 | sinazongwe
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20i%20n%20a%20z%20o%20n%20g%20w%20e%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 599 of Set 1 | astana
# http://api.openweathermap.org/data/2.5/weather?q=%20a%20s%20t%20a%20n%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 600 of Set 1 | pokhara
# http://api.openweathermap.org/data/2.5/weather?q=%20p%20o%20k%20h%20a%20r%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 601 of Set 1 | shingu
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20h%20i%20n%20g%20u%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 602 of Set 1 | santa cruz de tenerife
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20a%20n%20t%20a%20 %20c%20r%20u%20z%20 %20d%20e%20 %20t%20e%20n%20e%20r%20i%20f%20e%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 603 of Set 1 | san andres
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20a%20n%20 %20a%20n%20d%20r%20e%20s%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 604 of Set 1 | biak
# http://api.openweathermap.org/data/2.5/weather?q=%20b%20i%20a%20k%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 605 of Set 1 | eydhafushi
# http://api.openweathermap.org/data/2.5/weather?q=%20e%20y%20d%20h%20a%20f%20u%20s%20h%20i%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 606 of Set 1 | rayadrug
# http://api.openweathermap.org/data/2.5/weather?q=%20r%20a%20y%20a%20d%20r%20u%20g%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 607 of Set 1 | mokhsogollokh
# http://api.openweathermap.org/data/2.5/weather?q=%20m%20o%20k%20h%20s%20o%20g%20o%20l%20l%20o%20k%20h%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 608 of Set 1 | sakaiminato
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20a%20k%20a%20i%20m%20i%20n%20a%20t%20o%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 609 of Set 1 | palmas
# http://api.openweathermap.org/data/2.5/weather?q=%20p%20a%20l%20m%20a%20s%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 610 of Set 1 | yulara
# http://api.openweathermap.org/data/2.5/weather?q=%20y%20u%20l%20a%20r%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 611 of Set 1 | capaci
# http://api.openweathermap.org/data/2.5/weather?q=%20c%20a%20p%20a%20c%20i%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 612 of Set 1 | ewa beach
# http://api.openweathermap.org/data/2.5/weather?q=%20e%20w%20a%20 %20b%20e%20a%20c%20h%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 613 of Set 1 | russell
# http://api.openweathermap.org/data/2.5/weather?q=%20r%20u%20s%20s%20e%20l%20l%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 614 of Set 1 | yuzhno-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?q=%20y%20u%20z%20h%20n%20o%20-%20y%20e%20n%20i%20s%20e%20y%20s%20k%20i%20y%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 615 of Set 1 | sorvag
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20o%20r%20v%20a%20g%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# HTTP Error 404: Not Found
# Processing Record 616 of Set 1 | santona
# http://api.openweathermap.org/data/2.5/weather?q=%20s%20a%20n%20t%20o%20n%20a%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 617 of Set 1 | aras
# http://api.openweathermap.org/data/2.5/weather?q=%20a%20r%20a%20s%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# Processing Record 618 of Set 1 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?q=%20c%20a%20b%20e%20d%20e%20l%20o%20&units=imperial&APPID=df04bb1077dea60a218c4a0244319eab
# end of stats loop
# Could not get data for 71 cities

# %%
#Convert Raw Data to DataFrame
WeatherPy_df.count()
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Max Temp      547
# Wind Speed    547
# Lat           547
# Lng           547
# Humidity      547
# dtype: int64

# %%
#Export the city data into a .csv.
WeatherPy_df.to_csv("WeatherPy.csv",  index=False)
#Display the DataFrame
WeatherPy_df.head(10)
# Out:
#               City Cloudiness Country        Date Max Temp Wind Speed    Lat  \
# 0          Magadan         80      RU  1549258794      5.8      15.79  59.56
# 1          Mataura         88      NZ  1549258592    71.18      21.83 -46.19
# 2          Rikitea         12      PF  1549258575    81.85       7.74 -23.12
# 3  Bambous Virieux         40      MU  1549256400       86      11.41 -20.34
# 4     Punta Arenas          0      CL  1549256400     57.2      12.75 -53.16
# 5         Hermanus         92      ZA  1549258602    63.31       3.49 -34.42
# 6       Clonakilty         75      IE  1549256400     44.6       6.93  51.62
# 7      Port Alfred         32      ZA  1549258574    70.28      14.45 -33.59
# 8        Esperance         20      TT  1549256400     73.4       5.06  10.24
# 9             Hilo         90      US  1549255980    71.96      11.21  19.71
#
#       Lng Humidity
# 0   150.8      100
# 1  168.86       53
# 2 -134.97       99
# 3   57.76       79
# 4  -70.91       67
# 5   19.24       98
# 6   -8.87       93
# 7   26.89       86
# 8  -61.45       83
# 9 -155.08       84

# %%
#Latitude vs. Temperature Plot

plt.scatter(WeatherPy_df["Lat"],WeatherPy_df["Max Temp"],marker ="o",facecolor="coral", alpha=0.5)
plt.title("Latitude vs. Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel (" Max Temperature")
plt.figure(figsize=(6,8))
plt.show()
plt.savefig("Latitude vs. Temperature.png")

# %%
#Latitude vs. Humidity Plot
plt.scatter(WeatherPy_df["Lat"],WeatherPy_df["Humidity"],marker ="o",facecolor="red", alpha=0.8)
plt.title("Latitude vs. Humidity Plot")
plt.xlabel("Latitude")
plt.ylabel ("Humidity")
plt.figure(figsize=(10,8))
plt.show()
plt.savefig("Latitude vs. Humidity.png")

# %%
#Latitude vs. Cloudiness Plot
plt.scatter(WeatherPy_df["Lat"],WeatherPy_df["Cloudiness"],marker ="o",facecolor="blue", alpha=0.5)
plt.title("Latitude vs. Cloudiness Plot")
plt.xlabel("Latitude")
plt.ylabel ("Cloudiness")
plt.figure(figsize=(10,8))
plt.show()
plt.savefig("Latitude vs. Cloudiness.png")

# %%
#Latitude vs. Wind Speed Plot
plt.scatter(WeatherPy_df["Lat"],WeatherPy_df["Wind Speed"],marker ="o",facecolor="green", alpha=0.5)
plt.title("Latitude vs. Wind Speed Plot")
plt.xlabel("Latitude")
plt.ylabel ("Wind Speed")
plt.figure(figsize=(10,8))
plt.show()
plt.savefig("Latitude vs. Wind Speed.png")
